# %%
# List all files in data/raw_ping/ and for each one
# check if a parquet version already exists in the ping folder
# If not, decompress the bz2 file, parse it to parquet, and delete the decompressed version
# Process all files in parallel

import os
import subprocess
import json
import shutil
import pyarrow as pa
import dask.dataframe as dd
from dask.distributed import Client
import dask.bag as db
from concurrent.futures import ThreadPoolExecutor
from pathlib import Path

import threading

in_progress = set()
in_progress_lock = threading.Lock()

client = Client()
print(client.dashboard_link)

# Define the schema for parquet files
parquet_schema = pa.schema([
    pa.field("prb_id", pa.int64(), nullable=False),
    pa.field("dst_addr", pa.string(), nullable=False),
    pa.field("ts", pa.int64(), nullable=False),
    pa.field("sent", pa.int64(), nullable=False),
    pa.field("rcvd", pa.int64(), nullable=False),
    pa.field("avg", pa.float64(), nullable=True),
    pa.field("result", pa.string(), nullable=True),
])

raw_dir = "data/raw_ping/"
decomp_dir = "data/decomp_ping/"
ping_dir = "data/ping/"

# Ensure output directories exist
for d in [decomp_dir, ping_dir]:
    os.makedirs(d, exist_ok=True)

# Get all files in raw_dir
raw_files = [f for f in os.listdir(raw_dir) if os.path.isfile(os.path.join(raw_dir, f))]

print(f"Raw files: {raw_files}")

# Collect files that need to be processed
to_process = []
for raw_file in raw_files:
    base_name = os.path.splitext(raw_file)[0]
    parquet_path = os.path.join(ping_dir, base_name + '.parquet')
    
    # Check if parquet file already exists
    if not os.path.exists(parquet_path) and raw_file.endswith('.bz2'):
        to_process.append(raw_file)

print(f"To process: {to_process}")

def process_single_file(raw_file):
    """
    Decompress a bz2 file, parse it to parquet, and clean up the decompressed file
    """
    base_name = os.path.splitext(raw_file)[0]
    raw_path = os.path.join(raw_dir, raw_file)
    decomp_path = os.path.join(decomp_dir, base_name + '.json')
    parquet_path = os.path.join(ping_dir, base_name + '.parquet')
    

    print(f"Starting processing: {raw_file} -> {parquet_path}")

    with in_progress_lock:
        in_progress.add(decomp_path)
        in_progress.add(parquet_path)
    try:
        # Step 1: Decompress the bz2 file (skip if decompressed file already exists)
        if not os.path.exists(decomp_path):
            print(f"  Decompressing: {raw_file}")
            cmd = ["bzip2", "-dc", raw_path]
            with open(decomp_path, "wb") as f_out:
                subprocess.run(cmd, stdout=f_out, check=True)
        else:
            print(f"  Using existing decompressed file: {decomp_path}")

        # Remove already decompressed file from in_progress set
        with in_progress_lock:
            in_progress.discard(decomp_path)
        
        # Step 2: Parse the decompressed JSON to parquet
        print(f"  Parsing to parquet: {base_name}.json")
        
        # Read the decompressed file as a bag of lines
        bag = db.read_text(decomp_path, blocksize="128MB")
        
        # Parse JSON and filter
        processed_bag = (bag
            .map(json.loads)  # Parse JSON
            .filter(lambda r: r.get("sent", -1) == 3)  # Filter for sent == 3
            .map(lambda r: {  # Select and transform fields
                "prb_id": r["prb_id"],
                "dst_addr": r["dst_addr"],
                "ts": r["timestamp"],
                "sent": r["sent"],
                "rcvd": r["rcvd"],
                "avg": r.get("avg"),
                "result": json.dumps(r.get("result"))
            })
        )
        
        # Convert to DataFrame and save as parquet
        df = processed_bag.to_dataframe()
        df.to_parquet(parquet_path, engine='pyarrow', schema=parquet_schema)
        
        if os.path.exists(parquet_path):
            # Step 3: Clean up the decompressed file
            print(f"  Cleaning up: {decomp_path}")
            os.remove(decomp_path)
        else:
            print(f"  Parquet file not created: {parquet_path}, skipping cleanup of {decomp_path}")
            
        print(f"Completed processing: {raw_file} -> {parquet_path}")

        with in_progress_lock:
            in_progress.discard(parquet_path)
        
        return parquet_path
        
    except Exception as e:
        print(f"Error processing {raw_file}: {e}")
        # Clean up decompressed file if it exists and there was an error
        if os.path.exists(decomp_path):
            try:
                os.remove(decomp_path)
                print(f"  Cleaned up decompressed file after error: {decomp_path}")
            except:
                pass
        
        with in_progress_lock:
            in_progress.discard(decomp_path)
            in_progress.discard(parquet_path)
        
        return None

try:
    if to_process:
        with ThreadPoolExecutor() as executor:
            results = list(executor.map(process_single_file, to_process))
        
        # Report results
        successful = [r for r in results if r is not None]
        failed = len(results) - len(successful)
        
        print(f"\nProcessing complete!")
        print(f"Successfully processed: {len(successful)} files")
        print(f"Failed: {failed} files")
        
        if successful:
            print("Successfully created parquet files:")
            for result in successful:
                print(f"  {result}")
    else:
        print("No files to process.")
except KeyboardInterrupt:
    print("\nKeyboardInterrupt detected! Cleaning up unfinished files...")
    with in_progress_lock:
        for f in list(in_progress):
            if os.path.exists(f):
                try:
                    if os.path.isdir(f):
                        shutil.rmtree(f)
                        print(f"  Deleted unfinished directory: {f}")
                    else:
                        os.remove(f)
                        print(f"  Deleted unfinished file: {f}")
                except Exception as e:
                    print(f"  Could not delete {f}: {e}")
# Out:
# http://127.0.0.1:8787/status
# Raw files: ['ping-2025-06-24T0000.bz2', 'ping-2025-06-24T0100.bz2', 'ping-2025-06-24T0200.bz2', 'ping-2025-06-24T0300.bz2', 'ping-2025-06-24T0400.bz2', 'ping-2025-06-24T0500.bz2', 'ping-2025-06-24T0600.bz2', 'ping-2025-06-24T0700.bz2', 'ping-2025-06-24T0800.bz2', 'ping-2025-06-24T0900.bz2', 'ping-2025-06-24T1000.bz2', 'ping-2025-06-24T1100.bz2', 'ping-2025-06-24T1200.bz2', 'ping-2025-06-24T1300.bz2', 'ping-2025-06-24T1400.bz2', 'ping-2025-06-24T1500.bz2', 'ping-2025-06-24T1600.bz2', 'ping-2025-06-24T1700.bz2', 'ping-2025-06-24T1800.bz2', 'ping-2025-06-24T1900.bz2', 'ping-2025-06-24T2000.bz2', 'ping-2025-06-24T2100.bz2', 'ping-2025-06-24T2200.bz2', 'ping-2025-06-24T2300.bz2', 'ping-2025-06-25T0000.bz2', 'ping-2025-06-25T0100.bz2', 'ping-2025-06-25T0200.bz2', 'ping-2025-06-25T0300.bz2', 'ping-2025-06-25T0400.bz2', 'ping-2025-06-25T0500.bz2', 'ping-2025-06-25T0600.bz2', 'ping-2025-06-25T0700.bz2', 'ping-2025-06-25T0800.bz2', 'ping-2025-06-25T0900.bz2',
-11T1300.bz2', 'ping-2025-07-11T1400.bz2', 'ping-2025-07-11T1500.bz2', 'ping-2025-07-11T1600.bz2', 'ping-2025-07-11T1700.bz2', 'ping-2025-07-11T1800.bz2', 'ping-2025-07-11T1900.bz2', 'ping-2025-07-11T2000.bz2', 'ping-2025-07-11T2100.bz2', 'ping-2025-07-11T2200.bz2', 'ping-2025-07-11T2300.bz2', 'ping-2025-07-12T0000.bz2', 'ping-2025-07-12T0100.bz2', 'ping-2025-07-12T0200.bz2', 'ping-2025-07-12T0300.bz2', 'ping-2025-07-12T0400.bz2', 'ping-2025-07-12T0500.bz2', 'ping-2025- ...
# Starting processing: ping-2025-07-06T0800.bz2 -> data/ping/ping-2025-07-06T0800.parquet
# Starting processing: ping-2025-07-06T0900.bz2 -> data/ping/ping-2025-07-06T0900.parquet
#   Decompressing: ping-2025-07-06T0800.bz2
# Starting processing: ping-2025-07-06T1000.bz2 -> data/ping/ping-2025-07-06T1000.parquet
#   Decompressing: ping-2025-07-06T0900.bz2
# Starting processing: ping-2025-07-06T1100.bz2 -> data/ping/ping-2025-07-06T1100.parquet
# Starting processing: ping-2025-07-06T1200.bz2 -> data/ping/ping-2025-07-06T1200.parquet
# Starting processing: ping-2025-07-06T1300.bz2 -> data/ping/ping-2025-07-06T1300.parquet
# Starting processing: ping-2025-07-06T1400.bz2 -> data/ping/ping-2025-07-06T1400.parquet
# Starting processing: ping-2025-07-06T1500.bz2 -> data/ping/ping-2025-07-06T1500.parquet
# Starting processing: ping-2025-07-06T1600.bz2 -> data/ping/ping-2025-07-06T1600.parquet
#   Decompressing: ping-2025-07-06T1000.bz2
#   Decompressing: ping-2025-07-06T1500.bz2
#   Decompressing: ping-2025-07-06T1200.bz2
# Starting processing: ping-2025-07-06T1700.bz2 -> data/ping/ping-2025-07-06T1700.parquet
#   Decompressing: ping-2025-07-06T1300.bz2
#   Decompressing: ping-2025-07-06T1100.bz2
#   Decompressing: ping-2025-07-06T1400.bz2
# Starting processing: ping-2025-07-06T1800.bz2 -> data/ping/ping-2025-07-06T1800.parquet
# Starting processing: ping-2025-07-06T1900.bz2 -> data/ping/ping-2025-07-06T1900.parquet
# Starting processing: ping-2025-07-06T2000.bz2 -> data/ping/ping-2025-07-06T2000.parquet
# Starting processing: ping-2025-07-06T2100.bz2 -> data/ping/ping-2025-07-06T2100.parquet
# Starting processing: ping-2025-07-06T2200.bz2 -> data/ping/ping-2025-07-06T2200.parquet
# Starting processing: ping-2025-07-06T2300.bz2 -> data/ping/ping-2025-07-06T2300.parquet
# Starting processing: ping-2025-07-07T0000.bz2 -> data/ping/ping-2025-07-07T0000.parquet
# Starting processing: ping-2025-07-07T0100.bz2 -> data/ping/ping-2025-07-07T0100.parquet
# Starting processing: ping-2025-07-07T0200.bz2 -> data/ping/ping-2025-07-07T0200.parquet
# Starting processing: ping-2025-07-07T0300.bz2 -> data/ping/ping-2025-07-07T0300.parquet
#   Decompressing: ping-2025-07-06T1800.bz2
#   Decompressing: ping-2025-07-06T1700.bz2
#   Decompressing: ping-2025-07-06T2100.bz2
#   Decompressing: ping-2025-07-06T2200.bz2
#   Decompressing: ping-2025-07-06T1900.bz2
#   Decompressing: ping-2025-07-06T2000.bz2
# Starting processing: ping-2025-07-07T0400.bz2 -> data/ping/ping-2025-07-07T0400.parquet
#   Decompressing: ping-2025-07-06T2300.bz2
#   Decompressing: ping-2025-07-06T1600.bz2
#   Decompressing: ping-2025-07-07T0000.bz2
# Starting processing: ping-2025-07-07T0500.bz2 -> data/ping/ping-2025-07-07T0500.parquet
# Starting processing: ping-2025-07-07T0600.bz2 -> data/ping/ping-2025-07-07T0600.parquet
# Starting processing: ping-2025-07-07T0700.bz2 -> data/ping/ping-2025-07-07T0700.parquet
# Starting processing: ping-2025-07-07T0800.bz2 -> data/ping/ping-2025-07-07T0800.parquet
# Starting processing: ping-2025-07-07T0900.bz2 -> data/ping/ping-2025-07-07T0900.parquet
# Starting processing: ping-2025-07-07T1000.bz2 -> data/ping/ping-2025-07-07T1000.parquet
# Starting processing: ping-2025-07-07T1100.bz2 -> data/ping/ping-2025-07-07T1100.parquet
# Starting processing: ping-2025-07-07T1200.bz2 -> data/ping/ping-2025-07-07T1200.parquet
# Starting processing: ping-2025-07-07T1300.bz2 -> data/ping/ping-2025-07-07T1300.parquet
# Starting processing: ping-2025-07-07T1400.bz2 -> data/ping/ping-2025-07-07T1400.parquet
# Starting processing: ping-2025-07-07T1500.bz2 -> data/ping/ping-2025-07-07T1500.parquet
#   Decompressing: ping-2025-07-07T1000.bz2
#   Decompressing: ping-2025-07-07T0100.bz2
#   Decompressing: ping-2025-07-07T1500.bz2
#   Decompressing: ping-2025-07-07T0700.bz2
#   Decompressing: ping-2025-07-07T0400.bz2
#   Decompressing: ping-2025-07-07T1200.bz2
#   Decompressing: ping-2025-07-07T0800.bz2
#   Decompressing: ping-2025-07-07T0500.bz2
#   Decompressing: ping-2025-07-07T0300.bz2
#   Decompressing: ping-2025-07-07T0600.bz2
#   Decompressing: ping-2025-07-07T1300.bz2
#   Decompressing: ping-2025-07-07T0200.bz2
#   Decompressing: ping-2025-07-07T0900.bz2
#   Decompressing: ping-2025-07-07T1100.bz2
#   Decompressing: ping-2025-07-07T1400.bz2
#   Parsing to parquet: ping-2025-07-06T2300.json
#   Parsing to parquet: ping-2025-07-07T0700.json
#   Parsing to parquet: ping-2025-07-07T1500.json
#   Parsing to parquet: ping-2025-07-06T0800.json
#   Parsing to parquet: ping-2025-07-06T1000.json
#   Parsing to parquet: ping-2025-07-07T0600.json
#   Parsing to parquet: ping-2025-07-07T0400.json
#   Parsing to parquet: ping-2025-07-07T0300.json
#   Parsing to parquet: ping-2025-07-06T1400.json
#   Parsing to parquet: ping-2025-07-07T0800.json
#   Parsing to parquet: ping-2025-07-07T1200.json
#   Parsing to parquet: ping-2025-07-06T1500.json
#   Parsing to parquet: ping-2025-07-07T0200.json
#   Parsing to parquet: ping-2025-07-06T0900.json
#   Parsing to parquet: ping-2025-07-07T1100.json
#   Parsing to parquet: ping-2025-07-07T1000.json
#   Parsing to parquet: ping-2025-07-06T1300.json
#   Parsing to parquet: ping-2025-07-07T1300.json
#   Parsing to parquet: ping-2025-07-06T1100.json
#   Parsing to parquet: ping-2025-07-06T2000.json
#   Parsing to parquet: ping-2025-07-07T0500.json
#   Parsing to parquet: ping-2025-07-07T0100.json
#   Parsing to parquet: ping-2025-07-06T2200.json
#   Parsing to parquet: ping-2025-07-06T1700.json
#   Parsing to parquet: ping-2025-07-07T0900.json
#   Parsing to parquet: ping-2025-07-06T1900.json
#   Parsing to parquet: ping-2025-07-06T2100.json
#   Parsing to parquet: ping-2025-07-07T0000.json
#   Parsing to parquet: ping-2025-07-06T1200.json
#   Parsing to parquet: ping-2025-07-06T1600.json
#   Parsing to parquet: ping-2025-07-06T1800.json
#   Parsing to parquet: ping-2025-07-07T1400.json
#   Cleaning up: data/decomp_ping/ping-2025-07-06T2300.json
# Completed processing: ping-2025-07-06T2300.bz2 -> data/ping/ping-2025-07-06T2300.parquet
# Starting processing: ping-2025-07-07T1600.bz2 -> data/ping/ping-2025-07-07T1600.parquet
#   Decompressing: ping-2025-07-07T1600.bz2
#   Cleaning up: data/decomp_ping/ping-2025-07-07T0400.json
# Completed processing: ping-2025-07-07T0400.bz2 -> data/ping/ping-2025-07-07T0400.parquet
# Starting processing: ping-2025-07-07T1700.bz2 -> data/ping/ping-2025-07-07T1700.parquet
#   Decompressing: ping-2025-07-07T1700.bz2
#   Cleaning up: data/decomp_ping/ping-2025-07-07T0600.json
# Completed processing: ping-2025-07-07T0600.bz2 -> data/ping/ping-2025-07-07T0600.parquet
# Starting processing: ping-2025-07-07T1800.bz2 -> data/ping/ping-2025-07-07T1800.parquet
#   Decompressing: ping-2025-07-07T1800.bz2
#   Cleaning up: data/decomp_ping/ping-2025-07-07T0700.json
# Completed processing: ping-2025-07-07T0700.bz2 -> data/ping/ping-2025-07-07T0700.parquet
# Starting processing: ping-2025-07-07T1900.bz2 -> data/ping/ping-2025-07-07T1900.parquet
#   Decompressing: ping-2025-07-07T1900.bz2
#   Cleaning up: data/decomp_ping/ping-2025-07-07T1100.json
# Completed processing: ping-2025-07-07T1100.bz2 -> data/ping/ping-2025-07-07T1100.parquet
# Starting processing: ping-2025-07-07T2000.bz2 -> data/ping/ping-2025-07-07T2000.parquet
#   Decompressing: ping-2025-07-07T2000.bz2
#   Cleaning up: data/decomp_ping/ping-2025-07-07T1200.json
#   Cleaning up: data/decomp_ping/ping-2025-07-07T0100.json
#   Cleaning up: data/decomp_ping/ping-2025-07-06T1500.json
#   Cleaning up: data/decomp_ping/ping-2025-07-07T0200.json
#   Cleaning up: data/decomp_ping/ping-2025-07-06T1400.json
#   Cleaning up: data/decomp_ping/ping-2025-07-06T0800.json
# Completed processing: ping-2025-07-07T1200.bz2 -> data/ping/ping-2025-07-07T1200.parquet
# Starting processing: ping-2025-07-07T2100.bz2 -> data/ping/ping-2025-07-07T2100.parquet
#   Decompressing: ping-2025-07-07T2100.bz2
# Completed processing: ping-2025-07-07T0200.bz2 -> data/ping/ping-2025-07-07T0200.parquet
# Starting processing: ping-2025-07-07T2200.bz2 -> data/ping/ping-2025-07-07T2200.parquet
#   Decompressing: ping-2025-07-07T2200.bz2
#   Cleaning up: data/decomp_ping/ping-2025-07-07T1000.json
# Completed processing: ping-2025-07-06T1500.bz2 -> data/ping/ping-2025-07-06T1500.parquet
# Starting processing: ping-2025-07-07T2300.bz2 -> data/ping/ping-2025-07-07T2300.parquet
# Completed processing: ping-2025-07-06T1400.bz2 -> data/ping/ping-2025-07-06T1400.parquet
# Starting processing: ping-2025-07-08T0000.bz2 -> data/ping/ping-2025-07-08T0000.parquet
# Completed processing: ping-2025-07-07T0100.bz2 -> data/ping/ping-2025-07-07T0100.parquet
# Starting processing: ping-2025-07-08T0100.bz2 -> data/ping/ping-2025-07-08T0100.parquet
# Completed processing: ping-2025-07-06T0800.bz2 -> data/ping/ping-2025-07-06T0800.parquet
# Starting processing: ping-2025-07-08T0200.bz2 -> data/ping/ping-2025-07-08T0200.parquet
#   Decompressing: ping-2025-07-07T2300.bz2
#   Decompressing: ping-2025-07-08T0100.bz2
#   Decompressing: ping-2025-07-08T0000.bz2
#   Decompressing: ping-2025-07-08T0200.bz2
# Completed processing: ping-2025-07-07T1000.bz2 -> data/ping/ping-2025-07-07T1000.parquet
# Starting processing: ping-2025-07-08T0300.bz2 -> data/ping/ping-2025-07-08T0300.parquet
#   Decompressing: ping-2025-07-08T0300.bz2
#   Cleaning up: data/decomp_ping/ping-2025-07-07T0900.json
#   Cleaning up: data/decomp_ping/ping-2025-07-06T1000.json
# Completed processing: ping-2025-07-07T0900.bz2 -> data/ping/ping-2025-07-07T0900.parquet
# Starting processing: ping-2025-07-08T0400.bz2 -> data/ping/ping-2025-07-08T0400.parquet
# Completed processing: ping-2025-07-06T1000.bz2 -> data/ping/ping-2025-07-06T1000.parquet
# Starting processing: ping-2025-07-08T0500.bz2 -> data/ping/ping-2025-07-08T0500.parquet
#   Decompressing: ping-2025-07-08T0400.bz2
#   Decompressing: ping-2025-07-08T0500.bz2
#   Cleaning up: data/decomp_ping/ping-2025-07-07T0800.json
# Completed processing: ping-2025-07-07T0800.bz2 -> data/ping/ping-2025-07-07T0800.parquet
# Starting processing: ping-2025-07-08T0600.bz2 -> data/ping/ping-2025-07-08T0600.parquet
#   Decompressing: ping-2025-07-08T0600.bz2
#   Cleaning up: data/decomp_ping/ping-2025-07-07T0300.json
# Completed processing: ping-2025-07-07T0300.bz2 -> data/ping/ping-2025-07-07T0300.parquet
# Starting processing: ping-2025-07-08T0700.bz2 -> data/ping/ping-2025-07-08T0700.parquet
#   Decompressing: ping-2025-07-08T0700.bz2
#   Cleaning up: data/decomp_ping/ping-2025-07-06T1300.json
# Completed processing: ping-2025-07-06T1300.bz2 -> data/ping/ping-2025-07-06T1300.parquet
# Starting processing: ping-2025-07-08T0800.bz2 -> data/ping/ping-2025-07-08T0800.parquet
#   Decompressing: ping-2025-07-08T0800.bz2
#   Cleaning up: data/decomp_ping/ping-2025-07-06T1100.json
# Completed processing: ping-2025-07-06T1100.bz2 -> data/ping/ping-2025-07-06T1100.parquet
# Starting processing: ping-2025-07-08T0900.bz2 -> data/ping/ping-2025-07-08T0900.parquet
#   Decompressing: ping-2025-07-08T0900.bz2
#   Cleaning up: data/decomp_ping/ping-2025-07-06T2100.json
#   Cleaning up: data/decomp_ping/ping-2025-07-06T2000.json
#   Cleaning up: data/decomp_ping/ping-2025-07-07T1500.json
# Completed processing: ping-2025-07-06T2100.bz2 -> data/ping/ping-2025-07-06T2100.parquet
# Starting processing: ping-2025-07-08T1000.bz2 -> data/ping/ping-2025-07-08T1000.parquet
#   Decompressing: ping-2025-07-08T1000.bz2
# Completed processing: ping-2025-07-06T2000.bz2 -> data/ping/ping-2025-07-06T2000.parquet
# Starting processing: ping-2025-07-08T1100.bz2 -> data/ping/ping-2025-07-08T1100.parquet
#   Decompressing: ping-2025-07-08T1100.bz2
# Completed processing: ping-2025-07-07T1500.bz2 -> data/ping/ping-2025-07-07T1500.parquet
# Starting processing: ping-2025-07-08T1200.bz2 -> data/ping/ping-2025-07-08T1200.parquet
#   Decompressing: ping-2025-07-08T1200.bz2
#   Cleaning up: data/decomp_ping/ping-2025-07-06T1600.json
#   Cleaning up: data/decomp_ping/ping-2025-07-07T1300.json
# Completed processing: ping-2025-07-07T1300.bz2 -> data/ping/ping-2025-07-07T1300.parquet
# Starting processing: ping-2025-07-08T1300.bz2 -> data/ping/ping-2025-07-08T1300.parquet
#   Decompressing: ping-2025-07-08T1300.bz2
# Completed processing: ping-2025-07-06T1600.bz2 -> data/ping/ping-2025-07-06T1600.parquet
# Starting processing: ping-2025-07-08T1400.bz2 -> data/ping/ping-2025-07-08T1400.parquet
#   Decompressing: ping-2025-07-08T1400.bz2
#   Cleaning up: data/decomp_ping/ping-2025-07-06T1900.json
#   Cleaning up: data/decomp_ping/ping-2025-07-07T0500.json
#   Cleaning up: data/decomp_ping/ping-2025-07-06T1700.json
# Completed processing: ping-2025-07-06T1900.bz2 -> data/ping/ping-2025-07-06T1900.parquet
# Starting processing: ping-2025-07-08T1500.bz2 -> data/ping/ping-2025-07-08T1500.parquet
#   Decompressing: ping-2025-07-08T1500.bz2
# Completed processing: ping-2025-07-06T1700.bz2 -> data/ping/ping-2025-07-06T1700.parquet
# Starting processing: ping-2025-07-08T1600.bz2 -> data/ping/ping-2025-07-08T1600.parquet
#   Decompressing: ping-2025-07-08T1600.bz2
# Completed processing: ping-2025-07-07T0500.bz2 -> data/ping/ping-2025-07-07T0500.parquet
# Starting processing: ping-2025-07-08T1700.bz2 -> data/ping/ping-2025-07-08T1700.parquet
#   Decompressing: ping-2025-07-08T1700.bz2
#   Cleaning up: data/decomp_ping/ping-2025-07-06T2200.json
# Completed processing: ping-2025-07-06T2200.bz2 -> data/ping/ping-2025-07-06T2200.parquet
# Starting processing: ping-2025-07-08T1800.bz2 -> data/ping/ping-2025-07-08T1800.parquet
#   Decompressing: ping-2025-07-08T1800.bz2
#   Cleaning up: data/decomp_ping/ping-2025-07-07T1400.json
#   Cleaning up: data/decomp_ping/ping-2025-07-06T1200.json
#   Cleaning up: data/decomp_ping/ping-2025-07-07T0000.json
#   Cleaning up: data/decomp_ping/ping-2025-07-06T0900.json
#   Cleaning up: data/decomp_ping/ping-2025-07-06T1800.json
# Completed processing: ping-2025-07-07T1400.bz2 -> data/ping/ping-2025-07-07T1400.parquet
# Starting processing: ping-2025-07-08T1900.bz2 -> data/ping/ping-2025-07-08T1900.parquet
#   Decompressing: ping-2025-07-08T1900.bz2
# Completed processing: ping-2025-07-06T1200.bz2 -> data/ping/ping-2025-07-06T1200.parquet
# Starting processing: ping-2025-07-08T2000.bz2 -> data/ping/ping-2025-07-08T2000.parquet
#   Decompressing: ping-2025-07-08T2000.bz2
# Completed processing: ping-2025-07-07T0000.bz2 -> data/ping/ping-2025-07-07T0000.parquet
# Starting processing: ping-2025-07-08T2100.bz2 -> data/ping/ping-2025-07-08T2100.parquet
#   Decompressing: ping-2025-07-08T2100.bz2
# Completed processing: ping-2025-07-06T1800.bz2 -> data/ping/ping-2025-07-06T1800.parquet
# Starting processing: ping-2025-07-08T2200.bz2 -> data/ping/ping-2025-07-08T2200.parquet
#   Decompressing: ping-2025-07-08T2200.bz2
# Completed processing: ping-2025-07-06T0900.bz2 -> data/ping/ping-2025-07-06T0900.parquet
# Starting processing: ping-2025-07-08T2300.bz2 -> data/ping/ping-2025-07-08T2300.parquet
#   Decompressing: ping-2025-07-08T2300.bz2
#   Parsing to parquet: ping-2025-07-07T1600.json
#   Parsing to parquet: ping-2025-07-07T1700.json
#   Parsing to parquet: ping-2025-07-07T1800.json
#   Parsing to parquet: ping-2025-07-08T0800.json
#   Parsing to parquet: ping-2025-07-08T0700.json
#   Parsing to parquet: ping-2025-07-08T0600.json
#   Parsing to parquet: ping-2025-07-07T1900.json
#   Parsing to parquet: ping-2025-07-08T0000.json
#   Parsing to parquet: ping-2025-07-07T2000.json
#   Parsing to parquet: ping-2025-07-08T0900.json
#   Parsing to parquet: ping-2025-07-08T1400.json
#   Parsing to parquet: ping-2025-07-08T0100.json
#   Parsing to parquet: ping-2025-07-08T0500.json
#   Parsing to parquet: ping-2025-07-08T0300.json
#   Parsing to parquet: ping-2025-07-07T2200.json
#   Parsing to parquet: ping-2025-07-08T1000.json
#   Parsing to parquet: ping-2025-07-08T0400.json
#   Parsing to parquet: ping-2025-07-08T1500.json  Parsing to parquet: ping-2025-07-08T0200.json
#
#   Parsing to parquet: ping-2025-07-07T2300.json
#   Parsing to parquet: ping-2025-07-08T1100.json
#   Parsing to parquet: ping-2025-07-08T1300.json
#   Parsing to parquet: ping-2025-07-08T1200.json
#   Parsing to parquet: ping-2025-07-08T1700.json
#   Parsing to parquet: ping-2025-07-08T1600.json
#   Parsing to parquet: ping-2025-07-08T1800.json
#   Parsing to parquet: ping-2025-07-07T2100.json
#   Parsing to parquet: ping-2025-07-08T1900.json
#   Parsing to parquet: ping-2025-07-08T2200.json
#   Parsing to parquet: ping-2025-07-08T2300.json
#   Parsing to parquet: ping-2025-07-08T2000.json
#   Parsing to parquet: ping-2025-07-08T2100.json
#   Cleaning up: data/decomp_ping/ping-2025-07-07T1600.json
# Completed processing: ping-2025-07-07T1600.bz2 -> data/ping/ping-2025-07-07T1600.parquet
# Starting processing: ping-2025-07-09T0000.bz2 -> data/ping/ping-2025-07-09T0000.parquet
#   Decompressing: ping-2025-07-09T0000.bz2
#   Parsing to parquet: ping-2025-07-09T0000.json
# 2025-07-27 14:41:04,272 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:34281' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('toparquetdata-a96f261e5eedc019beb09852ad65db0d', 120), ('toparquetdata-5c48ae4b0635ebc6aee0b82d5cf693c6', 43), ('toparquetdata-0f608a6d83107ece33c493c628f93312', 46), ('toparquetdata-15bcf3db9e6117f10a805509bc8a2ff1', 60), ('toparquetdata-88dda372b93e36ea80814fa6d8a7c3e6', 74), ('toparquetdata-15bcf3db9e6117f10a805509bc8a2ff1', 78), ('toparquetdata-75dfc2d8aa1d4d1e1db2bdf12f14ce13', 12), ('toparquetdata-32be6fb4928b24bdfac7453d839ec562', 95), ('toparquetdata-007bcd979d6be11439614d469d04294e', 93), ('toparquetdata-54dd6bf94d3a74d6dce32bd8179347ec', 24), ('toparquetdata-5c48ae4b0635ebc6aee0b82d5cf693c6', 29), ('toparquetdata-ddef286e693d88bc2e946ad508d28d15', 82), ('toparquetdata-0f608a6d83107ece33c493c628f93312', 32), ('toparquetdata-15bcf3db9e6117f10a805509bc8a2ff1', 37), ('toparquetdata-0f608a6d83107ece33c493c628f93312', 41), ('toparquetdata-f9556ad3693f80af1460d89207eb7565', 41), ('toparquetdata-b23c68fa209f37336f56ea2ba5bc2512', 24), ('toparquetdata-509dcf848dcd6cf83c9aeae47d00721c', 60), ('toparquetdata-4694f9604c96d9f651943bce01fba0c3', 41), ('toparquetdata-c614adcae1858b2f90fcaef2c0a87edd', 70), ('toparquetdata-d0cd83da95dbd8f3cc2c8ce367324f1a', 22), ('toparquetdata-d0cd83da95dbd8f3cc2c8ce367324f1a', 49), ('toparquetdata-61e42b2cc4b53bd9debd053b6f5bd1fc', 12), ('toparquetdata-5c48ae4b0635ebc6aee0b82d5cf693c6', 51), ('toparquetdata-9fc727963ab558ebbaa3633867714ae4', 49), ('toparquetdata-b23c68fa209f37336f56ea2ba5bc2512', 19), ('toparquetdata-88dda372b93e36ea80814fa6d8a7c3e6', 91), ('toparquetdata-acbcd7a81e0c0ed63d9219d0ecf6a8a1', 120), ('toparquetdata-bad1e93e81e7efaf8c06eb351a0cfe08', 35), ('toparquetdata-5201dd49a56d6ec7e67687088dd04e3a', 45), ('toparquetdata-20ff974193f3a0a3821177ef64a74c06', 92), ('toparquetdata-a96f261e5eedc019beb09852ad65db0d', 96), ('toparquetdata-5201dd49a56d6ec7e67687088dd04e3a', 72), ('toparquetdata-0f608a6d83107ece33c493c628f93312', 4), ('toparquetdata-f9556ad3693f80af1460d89207eb7565', 4), ('toparquetdata-5c48ae4b0635ebc6aee0b82d5cf693c6', 37), ('toparquetdata-54dd6bf94d3a74d6dce32bd8179347ec', 117), ('toparquetdata-9fc727963ab558ebbaa3633867714ae4', 53), ('toparquetdata-0f608a6d83107ece33c493c628f93312', 31), ('toparquetdata-88dda372b93e36ea80814fa6d8a7c3e6', 50), ('toparquetdata-a07bb979b90a3621e3cde2aa1710f9df', 39), ('toparquetdata-c614adcae1858b2f90fcaef2c0a87edd', 42), ('toparquetdata-c614adcae1858b2f90fcaef2c0a87edd', 51), ('toparquetdata-4694f9604c96d9f651943bce01fba0c3', 31), ('toparquetdata-39d4641ecc74631f94fbdb1eaf52f8ff', 92), ('toparquetdata-bad1e93e81e7efaf8c06eb351a0cfe08', 30), ('toparquetdata-32be6fb4928b24bdfac7453d839ec562', 89), ('toparquetdata-d0cd83da95dbd8f3cc2c8ce367324f1a', 39), ('toparquetdata-20ff974193f3a0a3821177ef64a74c06', 96), ('toparquetdata-1eb124d43bd3149c0bc710adc5e71e1a', 90), ('toparquetdata-9e6d7b0cfbc9f2110d3ddada03c558a5', 19), ('toparquetdata-54dd6bf94d3a74d6dce32bd8179347ec', 94), ('toparquetdata-acbcd7a81e0c0ed63d9219d0ecf6a8a1', 7), ('toparquetdata-a07bb979b90a3621e3cde2aa1710f9df', 16), ('toparquetdata-acbcd7a81e0c0ed63d9219d0ecf6a8a1', 16), ('toparquetdata-0f608a6d83107ece33c493c628f93312', 17), ('toparquetdata-15bcf3db9e6117f10a805509bc8a2ff1', 22), ('toparquetdata-f9556ad3693f80af1460d89207eb7565', 17), ('toparquetdata-88dda372b93e36ea80814fa6d8a7c3e6', 45), ('toparquetdata-007bcd979d6be11439614d469d04294e', 28), ('toparquetdata-c614adcae1858b2f90fcaef2c0a87edd', 37), ('toparquetdata-88dda372b93e36ea80814fa6d8a7c3e6', 72), ('toparquetdata-007bcd979d6be11439614d469d04294e', 46), ('toparquetdata-39d4641ecc74631f94fbdb1eaf52f8ff', 78), ('toparquetdata-32be6fb4928b24bdfac7453d839ec562', 66), ('toparquetdata-dc149a9bf8e5d0d3381933f192c9dcdb', 72), ('toparquetdata-39d4641ecc74631f94fbdb1eaf52f8ff', 96), ('toparquetdata-a96f261e5eedc019beb09852ad65db0d',
('toparquetdata-5c48ae4b0635ebc6aee0b82d5cf693c6', 37)
# State:     executing
# Task:  <Task ('toparquetdata-5c48ae4b0635ebc6aee0b82d5cf693c6', 37) to-parquet(...)>
# Exception: "FileNotFoundError(2, 'No such file or directory')"
# Traceback: '  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/dask/dataframe/io/parquet/core.py", line 158, in __call__\n    return self.engine.write_partition(\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/dask/dataframe/io/parquet/arrow.py", line 852, in write_partition\n    with fs.open(fs.sep.join([path, filename]), "wb") as fil:\n         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/fsspec/spec.py", line 1338, in open\n    f = self._open(\n        ^^^^^^^^^^^\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/fsspec/implementations/local.py", line 206, in _open\n    return LocalFileOpener(path, mode, fs=self, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/fsspec/implementations/local.py", line 383, in __init__\n    self._open()\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/fsspec/implementations/local.py", line 388, in _open\n    self.f = open(self.path, mode=self.mode)\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n'
#
# 2025-07-27 15:25:13,857 - distributed.worker - ERROR - Compute Failed
# Key:       ('toparquetdata-15bcf3db9e6117f10a805509bc8a2ff1', 41)
# State:     executing
# Task:  <Task ('toparquetdata-15bcf3db9e6117f10a805509bc8a2ff1', 41) to-parquet(...)>
# Exception: "FileNotFoundError(2, 'No such file or directory')"
# Traceback: '  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/dask/dataframe/io/parquet/core.py", line 158, in __call__\n    return self.engine.write_partition(\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/dask/dataframe/io/parquet/arrow.py", line 852, in write_partition\n    with fs.open(fs.sep.join([path, filename]), "wb") as fil:\n         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/fsspec/spec.py", line 1338, in open\n    f = self._open(\n        ^^^^^^^^^^^\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/fsspec/implementations/local.py", line 206, in _open\n    return LocalFileOpener(path, mode, fs=self, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/fsspec/implementations/local.py", line 383, in __init__\n    self._open()\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/fsspec/implementations/local.py", line 388, in _open\n    self.f = open(self.path, mode=self.mode)\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n'
#
# 2025-07-27 15:25:13,860 - distributed.worker - ERROR - Compute Failed
# Key:       ('toparquetdata-c614adcae1858b2f90fcaef2c0a87edd', 39)
# State:     executing
# Task:  <Task ('toparquetdata-c614adcae1858b2f90fcaef2c0a87edd', 39) to-parquet(...)>
# Exception: "FileNotFoundError(2, 'No such file or directory')"
# Traceback: '  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/dask/dataframe/io/parquet/core.py", line 158, in __call__\n    return self.engine.write_partition(\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/dask/dataframe/io/parquet/arrow.py", line 852, in write_partition\n    with fs.open(fs.sep.join([path, filename]), "wb") as fil:\n         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/fsspec/spec.py", line 1338, in open\n    f = self._open(\n        ^^^^^^^^^^^\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/fsspec/implementations/local.py", line 206, in _open\n    return LocalFileOpener(path, mode, fs=self, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/fsspec/implementations/local.py", line 383, in __init__\n    self._open()\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/fsspec/implementations/local.py", line 388, in _open\n    self.f = open(self.path, mode=self.mode)\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n'
# Error processing ping-2025-07-07T2000.bz2: [Errno 2] No such file or directory: '/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/data/ping/ping-2025-07-07T2000.parquet/part.41.parquet'
# Error processing ping-2025-07-08T1900.bz2: [Errno 2] No such file or directory: '/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/data/ping/ping-2025-07-08T1900.parquet/part.37.parquet'
# Error processing ping-2025-07-08T0400.bz2: [Errno 2] No such file or directory: '/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/data/ping/ping-2025-07-08T0400.parquet/part.41.parquet'
#   Cleaned up decompressed file after error: data/decomp_ping/ping-2025-07-08T1900.json
#   Cleaned up decompressed file after error: data/decomp_ping/ping-2025-07-07T2000.json
#   Cleaned up decompressed file after error: data/decomp_ping/ping-2025-07-08T0400.json
# 2025-07-27 15:25:14,897 - distributed.worker - ERROR - Compute Failed
# Key:       ('toparquetdata-15bcf3db9e6117f10a805509bc8a2ff1', 40)
# State:     executing
# Task:  <Task ('toparquetdata-15bcf3db9e6117f10a805509bc8a2ff1', 40) to-parquet(...)>
# Exception: "FileNotFoundError(2, 'No such file or directory')"
# Traceback: '  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/dask/dataframe/io/parquet/core.py", line 158, in __call__\n    return self.engine.write_partition(\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/dask/dataframe/io/parquet/arrow.py", line 852, in write_partition\n    with fs.open(fs.sep.join([path, filename]), "wb") as fil:\n         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/fsspec/spec.py", line 1338, in open\n    f = self._open(\n        ^^^^^^^^^^^\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/fsspec/implementations/local.py", line 206, in _open\n    return LocalFileOpener(path, mode, fs=self, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/fsspec/implementations/local.py", line 383, in __init__\n    self._open()\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/fsspec/implementations/local.py", line 388, in _open\n    self.f = open(self.path, mode=self.mode)\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n'
#
# 2025-07-27 15:26:43,093 - distributed.worker - ERROR - Compute Failed
# Key:       ('toparquetdata-5378445d4c83434098f711ae6c64438a', 99)
# State:     executing
# Task:  <Task ('toparquetdata-5378445d4c83434098f711ae6c64438a', 99) to-parquet(...)>
# Exception: "FileNotFoundError(2, 'No such file or directory')"
# Traceback: '  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/dask/dataframe/io/parquet/core.py", line 158, in __call__\n    return self.engine.write_partition(\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/dask/dataframe/io/parquet/arrow.py", line 852, in write_partition\n    with fs.open(fs.sep.join([path, filename]), "wb") as fil:\n         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/fsspec/spec.py", line 1338, in open\n    f = self._open(\n        ^^^^^^^^^^^\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/fsspec/implementations/local.py", line 206, in _open\n    return LocalFileOpener(path, mode, fs=self, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/fsspec/implementations/local.py", line 383, in __init__\n    self._open()\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/fsspec/implementations/local.py", line 388, in _open\n    self.f = open(self.path, mode=self.mode)\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n'
# Error processing ping-2025-07-08T2300.bz2: [Errno 2] No such file or directory: '/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/data/ping/ping-2025-07-08T2300.parquet/part.99.parquet'
#   Cleaned up decompressed file after error: data/decomp_ping/ping-2025-07-08T2300.json
# 2025-07-27 15:26:44,039 - distributed.worker - ERROR - Compute Failed
# Key:       ('toparquetdata-298de082cc44b195755ada1d06292598', 99)
# State:     executing
# Task:  <Task ('toparquetdata-298de082cc44b195755ada1d06292598', 99) to-parquet(...)>
# Exception: "FileNotFoundError(2, 'No such file or directory')"
# Traceback: '  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/dask/dataframe/io/parquet/core.py", line 158, in __call__\n    return self.engine.write_partition(\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/dask/dataframe/io/parquet/arrow.py", line 852, in write_partition\n    with fs.open(fs.sep.join([path, filename]), "wb") as fil:\n         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/fsspec/spec.py", line 1338, in open\n    f = self._open(\n        ^^^^^^^^^^^\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/fsspec/implementations/local.py", line 206, in _open\n    return LocalFileOpener(path, mode, fs=self, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/fsspec/implementations/local.py", line 383, in __init__\n    self._open()\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/fsspec/implementations/local.py", line 388, in _open\n    self.f = open(self.path, mode=self.mode)\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n'
# Error processing ping-2025-07-08T2100.bz2: [Errno 2] No such file or directory: '/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/data/ping/ping-2025-07-08T2100.parquet/part.99.parquet'
#   Cleaned up decompressed file after error: data/decomp_ping/ping-2025-07-08T2100.json
# 2025-07-27 15:26:54,003 - distributed.worker - ERROR - Compute Failed
# Key:       ('toparquetdata-e580edcf86f718620d334f98a171ca29', 98)
# State:     executing
# Task:  <Task ('toparquetdata-e580edcf86f718620d334f98a171ca29', 98) to-parquet(...)>
# Exception: "FileNotFoundError(2, 'No such file or directory')"
# Traceback: '  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/dask/dataframe/io/parquet/core.py", line 158, in __call__\n    return self.engine.write_partition(\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/dask/dataframe/io/parquet/arrow.py", line 852, in write_partition\n    with fs.open(fs.sep.join([path, filename]), "wb") as fil:\n         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/fsspec/spec.py", line 1338, in open\n    f = self._open(\n        ^^^^^^^^^^^\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/fsspec/implementations/local.py", line 206, in _open\n    return LocalFileOpener(path, mode, fs=self, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/fsspec/implementations/local.py", line 383, in __init__\n    self._open()\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/fsspec/implementations/local.py", line 388, in _open\n    self.f = open(self.path, mode=self.mode)\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n'
# Error processing ping-2025-07-08T2000.bz2: [Errno 2] No such file or directory: '/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/data/ping/ping-2025-07-08T2000.parquet/part.98.parquet'
#   Cleaned up decompressed file after error: data/decomp_ping/ping-2025-07-08T2000.json
#   Cleaning up: data/decomp_ping/ping-2025-07-08T0700.json
# Completed processing: ping-2025-07-08T0700.bz2 -> data/ping/ping-2025-07-08T0700.parquet
#   Cleaning up: data/decomp_ping/ping-2025-07-08T1700.json
# Completed processing: ping-2025-07-08T1700.bz2 -> data/ping/ping-2025-07-08T1700.parquet
# 2025-07-27 15:27:30,515 - distributed.worker - ERROR - Compute Failed
# Key:       ('toparquetdata-b4a4f9728062a7ea3005f481629eadc1', 89)
# State:     executing
# Task:  <Task ('toparquetdata-b4a4f9728062a7ea3005f481629eadc1', 89) to-parquet(...)>
# Exception: "FileNotFoundError(2, 'No such file or directory')"
# Traceback: '  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/dask/dataframe/io/parquet/core.py", line 158, in __call__\n    return self.engine.write_partition(\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/dask/dataframe/io/parquet/arrow.py", line 852, in write_partition\n    with fs.open(fs.sep.join([path, filename]), "wb") as fil:\n         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/fsspec/spec.py", line 1338, in open\n    f = self._open(\n        ^^^^^^^^^^^\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/fsspec/implementations/local.py", line 206, in _open\n    return LocalFileOpener(path, mode, fs=self, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/fsspec/implementations/local.py", line 383, in __init__\n    self._open()\n  File "/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/.venv/lib/python3.12/site-packages/fsspec/implementations/local.py", line 388, in _open\n    self.f = open(self.path, mode=self.mode)\n             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n'
# Error processing ping-2025-07-09T0000.bz2: [Errno 2] No such file or directory: '/scratch/workspace/zevwilson_umass_edu-simple/ping-ingest/data/ping/ping-2025-07-09T0000.parquet/part.89.parquet'
#   Cleaned up decompressed file after error: data/decomp_ping/ping-2025-07-09T0000.json
